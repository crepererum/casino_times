# %%
include("../julia/lib.jl")
include("../julia/pruning_test.jl")

map_i2s, map_s2i = loadmap("../cpp/build/k-stems.map")
n = length(map_i2s)
m = 256
data = loaddata("../cpp/build/d0.data", m, n)

year_first = 1753
print()

# %%
plot_wavelet_report(data, map_s2i, year_first, "kiss", 0.001)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3c424dd77f0>)
# PyObject <matplotlib.text.Text object at 0x3c424426358>
