# %%
include("../julia/lib.jl")
include("../julia/pruning_test.jl")

map_i2s, map_s2i = loadmap("../data/final.map")
n = length(map_i2s)
m = 256
data = loaddata("../data/v0.data", m, n)

year_first = 1753
print()

# %%
plot_wavelet_report(data, map_s2i, year_first, "kiss", 0.04)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f331c0e96a0>)
# PyObject <matplotlib.text.Text object at 0x7f3311ce46a0>
